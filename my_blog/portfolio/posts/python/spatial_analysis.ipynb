# %% [raw]
# ---
# title: "Geospatial Analysis in Python"
# subtitle: "*A Case Study using Duckdb, Polars and Folium*"
# author-title: "Author"
# author: Jesus L. Monroy
# abstract-title: "Abstract"
# abstract: >
#     Geospatial analysis involves the application of spatial concepts and techniques to data that has geographic coordinates.
#     With the rise of big data and the increasing availability of geospatial information, the demand for effective geospatial analysis tools has grown significantly.
#     Python, with its rich ecosystem of libraries, has emerged as a powerful and popular choice for geospatial data scientists.<br>
# published-title: "Published"
# date: "2025-01-02"
# date-format: MMM, YYYY
# execute:
#     echo: true
# format:
#     html:
#         toc: true
#         toc-depth: 4
#         toc-title: Table of Contents
#         toc-location: left
#         page-layout: article
#         citation-location: margin
#         fig-cap-location: margin
#         tbl-cap-location: margin
#         grid:
#           sidebar-width: 250px
#           body-width: 950px
#           margin-width: 100px
#         self-contained: true
#         code-fold: show
#         embed-resources: true
#         html-math-method: katex
#         other-links:
#           - text: Medium
#             icon: medium
#             href: https://medium.com/@jesus_lmonroy
#           - text: Linkedin
#             icon: linkedin
#             href: https://www.linkedin.com/in/j3sus-lmonroy
#           - text: Twitter
#             icon: twitter
#             href: https://x.com/j3suslm
# code-line-numbers: false
# code-copy: false
# code-overflow: wrap
# jupyter: python3
# categories: [python]
# image: https://miro.medium.com/v2/resize:fit:1400/0*XuBHZzSmxp8sKmHC.png
# ---

# %% [markdown]
# ::: {#fig-etl}
#
# ![](images/geospatial.png){fig-align="left" width=30%}
#
# Image by Henrikki Tenkanen, Vuokko Heikinheimo, David Whipp
#
# :::

# %% [markdown]
# ## Environment setting

# %%
# import libraries
import numpy as np
import pandas as pd
import polars as pl
import duckdb as db
import folium
from great_tables import GT, md
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Data collection

# %%
conn = db.connect('datasets/geospatial.db')

# %%
conn.sql('show tables')
# Out:
# ┌─────────┐
# │  name   │
# │ varchar │
# ├─────────┤
# │ zomato  │
# └─────────┘

# %%
data = conn.sql('select * from zomato').pl()

# %%
data.columns
# Out:
# ['url',
#  'address',
#  'name',
#  'online_order',
#  'book_table',
#  'rate',
#  'votes',
#  'phone',
#  'location',
#  'rest_type',
#  'dish_liked',
#  'cuisines',
#  'approx_cost(for two people)',
#  'reviews_list',
#  'menu_item',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
data.shape
# Out:
# (51717, 17)

# %% [markdown]
# ## Data preprocessing

# %%
data.is_duplicated().sum()
# Out:
# 0

# %%
data.select(pl.all().is_null().sum()).to_dicts()
# Out:
# [{'url': 0,
#   'address': 0,
#   'name': 0,
#   'online_order': 0,
#   'book_table': 0,
#   'rate': 7775,
#   'votes': 0,
#   'phone': 1208,
#   'location': 21,
#   'rest_type': 227,
#   'dish_liked': 28078,
#   'cuisines': 45,
#   'approx_cost(for two people)': 346,
#   'reviews_list': 0,
#   'menu_item': 0,
#   'listed_in(type)': 0,
#   'listed_in(city)': 0}]

# %%
# As we have few missing values in location feature ,then we can drop the null
data = data.drop_nulls(subset=pl.col('location'))

# %%
#| label: tbl-head
#| tbl-cap: "Zomato Restaurants from Singh, S (2024) Geospatial Data Science in Python"
(
    GT(data.select('address','name','rate','votes','location','rest_type','dish_liked','cuisines').head(3))
    .tab_header(
        title=md('Zomato Restaurants')
    )
    .cols_width(
        cases={'rate':'50px',
              }
               )
    .tab_source_note(source_note=md('<br> *Source: Shan Singh*'))
)
# Out:
# GT(_tbl_data=shape: (3, 8)
# ┌─────────────┬─────────────┬───────┬───────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ address     ┆ name        ┆ rate  ┆ votes ┆ location    ┆ rest_type   ┆ dish_liked  ┆ cuisines   │
# │ ---         ┆ ---         ┆ ---   ┆ ---   ┆ ---         ┆ ---         ┆ ---         ┆ ---        │
# │ str         ┆ str         ┆ str   ┆ i64   ┆ str         ┆ str         ┆ str         ┆ str        │
# ╞═════════════╪═════════════╪═══════╪═══════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 942, 21st   ┆ Jalsa       ┆ 4.1/5 ┆ 775   ┆ Banashankar ┆ Casual      ┆ Pasta,      ┆ North      │
# │ Main Road,  ┆             ┆       ┆       ┆ i           ┆ Dining      ┆ Lunch       ┆ Indian,    │
# │ 2nd Stage…  ┆             ┆       ┆       ┆             ┆             ┆ Buffet,     ┆ Mughlai,   │
# │             ┆             ┆       ┆       ┆             ┆             ┆ Masala Pa…  ┆ Chinese    │
# │ 2nd Floor,  ┆ Spice       ┆ 4.1/5 ┆ 787   ┆ Banashankar ┆ Casual      ┆ Momos,      ┆ Chinese,   │
# │ 80 Feet     ┆ Elephant    ┆       ┆       ┆ i           ┆ Dining      ┆ Lunch       ┆ North      │
# │ Road, Near  ┆             ┆       ┆       ┆             ┆             ┆ Buffet,     ┆ Indian,    │
# │ …           ┆             ┆       ┆       ┆             ┆             ┆ Chocolate…  ┆ Thai       │
# │ 1112, Next  ┆ San Churro  ┆ 3.8/5 ┆ 918   ┆ Banashankar ┆ Cafe,       ┆ Churros,    ┆ Cafe,      │
# │ to KIMS     ┆ Cafe        ┆       ┆       ┆ i           ┆ Casual      ┆ Cannelloni, ┆ Mexican,   │
# │ Medical     ┆             ┆       ┆       ┆             ┆ Dining      ┆ Minestron…  ┆ Italian    │
# │ Col…        ┆             ┆       ┆       ┆             ┆             ┆             ┆            │
# └─────────────┴─────────────┴───────┴───────┴─────────────┴─────────────┴─────────────┴────────────┘, _body=<great_tables._gt_data.Body object at 0x305f1c2c0>, _boxhead=Boxhead([ColInfo(var='address', type=<ColInfoTypeEnum.default: 1>, column_label='address', column_align='left', column_width=None), ColInfo(var='name', type=<ColInfoTypeEnum.default: 1>, column_label='name', column_align='left', column_width=None), ColInfo(var='rate', type=<ColInfoTypeEnum.default: 1>, column_label='rate', column_align='left', column_width='50px'), ColInfo(var='votes', type=<ColInfoTypeEnum.default: 1>, column_label='votes', column_align='right', column_width=None), ColInfo(var='location', type=<ColInfoTypeEnum.default: 1>, column_label='location', column_align='left', column_width=None), ColInfo(var='rest_type', type=<ColInfoTypeEnum.default: 1>, column_label='rest_type', column_align='left', column_width=None), ColInfo(var='dish_liked', type=<ColInfoTypeEnum.default: 1>, column_label='dish_liked', column_align='left', column_width=None), ColInfo(var='cuisines', type=<ColInfoTypeEnum.default: 1>, column_label='cuisines', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x2cd8035f0>, _spanners=Spanners([]), _heading=Heading(title=Md(text='Zomato Restaurants'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[Md(text='<br> *Source: Shan Singh*')], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x305b38b30>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss ...

# %%
# create a copy
df = data.clone()

# %% [markdown]
# Lets make every place more readible so that u will get more more accurate geographical co-ordinates..

# %%
df = df.with_columns(
    location=(pl.col('location') + ', Bangalore, Karnataka, India')
)

# %%
df.select('location').sample(5).to_dicts()
# Out:
# [{'location': 'HSR, Bangalore, Karnataka, India'},
#  {'location': 'BTM, Bangalore, Karnataka, India'},
#  {'location': 'BTM, Bangalore, Karnataka, India'},
#  {'location': 'BTM, Bangalore, Karnataka, India'},
#  {'location': 'BTM, Bangalore, Karnataka, India'}]

# %%
df.schema
# Out:
# Schema([('url', String),
#         ('address', String),
#         ('name', String),
#         ('online_order', Boolean),
#         ('book_table', Boolean),
#         ('rate', String),
#         ('votes', Int64),
#         ('phone', String),
#         ('location', String),
#         ('rest_type', String),
#         ('dish_liked', String),
#         ('cuisines', String),
#         ('approx_cost(for two people)', String),
#         ('reviews_list', String),
#         ('menu_item', String),
#         ('listed_in(type)', String),
#         ('listed_in(city)', String)])

# %% [markdown]
# ## Extract coordinates from data

# %% [markdown]
# first we will learn how to extract Latitudes & longitudes using 'location' feature

# %%
rest_loc = pl.DataFrame()

# %%
rest_loc = pl.DataFrame({'name': df.select('location').unique()})

# %%
rest_loc.sample(5).to_dicts()
# Out:
# [{'name': 'Jakkur, Bangalore, Karnataka, India'},
#  {'name': 'Kalyan Nagar, Bangalore, Karnataka, India'},
#  {'name': 'RT Nagar, Bangalore, Karnataka, India'},
#  {'name': 'Koramangala 7th Block, Bangalore, Karnataka, India'},
#  {'name': 'Kaggadasapura, Bangalore, Karnataka, India'}]

# %%
# Nominatim is a tool to search OpenStreetMap data by address or location
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='app', timeout=None)

# %%
lat = [] # define lat list to store all the latitudes
lon = [] # define lon list to store all the longitudes

for name in pl.Series(rest_loc.select('name')):
    location = geolocator.geocode(name)
    
    if location is None:
        lat.append(np.nan)
        lon.append(np.nan)
        
    else:
        lat.append(location.latitude)
        lon.append(location.longitude)

# %%
lat[:10]
# Out:
# [13.0621474,
#  12.9846713,
#  12.981015523680384,
#  12.985098650000001,
#  12.9096941,
#  nan,
#  12.9067683,
#  12.938455602031697,
#  12.9176571,
#  12.9489339]

# %%
rest_loc = rest_loc.with_columns(
    lat=pl.Series(lat), # For python lists, construct a Series
    lon=pl.Series(lon),
)

# %%
#| label: tbl-rest_loc
#| tbl-cap: "Zomato restaurants coordinates from Singh, S (2024) Geospatial Data Science in Python"
(
    GT(rest_loc.head(5), auto_align=True)
    .tab_header(
        title=md('Zomato Restaurants Coordinates')
    )
    .fmt_number(columns=['lat','lon'], decimals=4, use_seps=False)
    .cols_width(
        cases={'name':'200%',
               'lat':'90%',
               'lon':'90%',
              }
               )
    .tab_source_note(source_note=md('<br>*Source: Shan Singh*'))
)
# Out:
# GT(_tbl_data=shape: (5, 3)
# ┌─────────────────────────────────┬───────────┬───────────┐
# │ name                            ┆ lat       ┆ lon       │
# │ ---                             ┆ ---       ┆ ---       │
# │ str                             ┆ f64       ┆ f64       │
# ╞═════════════════════════════════╪═══════════╪═══════════╡
# │ Sahakara Nagar, Bangalore, Kar… ┆ 13.062147 ┆ 77.580061 │
# │ Kaggadasapura, Bangalore, Karn… ┆ 12.984671 ┆ 77.679091 │
# │ Infantry Road, Bangalore, Karn… ┆ 12.981016 ┆ 77.602133 │
# │ CV Raman Nagar, Bangalore, Kar… ┆ 12.985099 ┆ 77.663117 │
# │ JP Nagar, Bangalore, Karnataka… ┆ 12.909694 ┆ 77.586607 │
# └─────────────────────────────────┴───────────┴───────────┘, _body=<great_tables._gt_data.Body object at 0x306aaac30>, _boxhead=Boxhead([ColInfo(var='name', type=<ColInfoTypeEnum.default: 1>, column_label='name', column_align='left', column_width='200%'), ColInfo(var='lat', type=<ColInfoTypeEnum.default: 1>, column_label='lat', column_align='right', column_width='90%'), ColInfo(var='lon', type=<ColInfoTypeEnum.default: 1>, column_label='lon', column_align='right', column_width='90%')]), _stub=<great_tables._gt_data.Stub object at 0x309d25820>, _spanners=Spanners([]), _heading=Heading(title=Md(text='Zomato Restaurants Coordinates'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[Md(text='<br>*Source: Shan Singh*')], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x306ace600>, _formats=[<great_tables._gt_data.FormatInfo object at 0x306aab7d0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value= ...

# %% [markdown]
# We have found out latitude and longitude of each location listed in the dataset using geopy
# This is used to plot maps.

# %%
pl.Series(rest_loc.select('lat')).is_null().sum()
# Out:
# 0

# %%
pl.Series(rest_loc.select('lat')).is_nan().sum()
# Out:
# 2

# %%
rest_loc.filter(pl.col('lat').is_nan())
# Out:
# shape: (2, 3)
# ┌─────────────────────────────────┬─────┬─────┐
# │ name                            ┆ lat ┆ lon │
# │ ---                             ┆ --- ┆ --- │
# │ str                             ┆ f64 ┆ f64 │
# ╞═════════════════════════════════╪═════╪═════╡
# │ Sadashiv Nagar, Bangalore, Kar… ┆ NaN ┆ NaN │
# │ Rammurthy Nagar, Bangalore, Ka… ┆ NaN ┆ NaN │
# └─────────────────────────────────┴─────┴─────┘

# %%
rest_loc = rest_loc.drop_nans()

# %% [markdown]
# ## Where are most number of restaurants located in Bengalore?

# %%
rest_locations = pl.Series(df.select('location')).value_counts(sort=True, name='total')

# %%
rest_locations = rest_locations.rename({'location':'name', 'total':'count'})

# %%
#| label: tbl-rest_count
#| tbl-cap: "Zomato restaurants count from Singh, S (2024) Geospatial Data Science in Python"
(
    GT(rest_locations.head(), auto_align=True)
    .tab_header(
        title=md('Zomato Restaurants Count')
    )
    .cols_width(cases={'name': '200%',})
    .tab_source_note(source_note=md('<br>*Source: Shan Singh*'))
)
# Out:
# GT(_tbl_data=shape: (5, 2)
# ┌─────────────────────────────────┬───────┐
# │ name                            ┆ count │
# │ ---                             ┆ ---   │
# │ str                             ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ BTM, Bangalore, Karnataka, Ind… ┆ 5124  │
# │ HSR, Bangalore, Karnataka, Ind… ┆ 2523  │
# │ Koramangala 5th Block, Bangalo… ┆ 2504  │
# │ JP Nagar, Bangalore, Karnataka… ┆ 2235  │
# │ Whitefield, Bangalore, Karnata… ┆ 2144  │
# └─────────────────────────────────┴───────┘, _body=<great_tables._gt_data.Body object at 0x306b085f0>, _boxhead=Boxhead([ColInfo(var='name', type=<ColInfoTypeEnum.default: 1>, column_label='name', column_align='left', column_width='200%'), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='center', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x2cd800920>, _spanners=Spanners([]), _heading=Heading(title=Md(text='Zomato Restaurants Count'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[Md(text='<br>*Source: Shan Singh*')], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x306aaaed0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value' ...

# %% [markdown]
# Now we can say that these are locations where most of restaurants are located.
#
# Lets create Heatmap of this results so that it becomes more user-friendly.
#
# Now, in order to perform spatial analysis, we need latitudes & longitudes of every location, so lets merge both dataframes in order to get geographical co-ordinates.

# %%
beng_rest_locations = rest_locations.join(rest_loc, on='name')

# %%
#| label: tbl-rest_count_coords
#| tbl-cap: "Zomato restaurants count and coordinates from Singh, S (2024) Geospatial Data Science in Python"
(
    GT(beng_rest_locations.head(), auto_align=True)
    .tab_header(
        title=md('Zomato Restaurants Count & coordinates')
    )
    .cols_width(cases={'name': '200%',})
    .tab_source_note(source_note=md('<br>*Source: Shan Singh*'))
)
# Out:
# GT(_tbl_data=shape: (5, 4)
# ┌─────────────────────────────────┬───────┬───────────┬───────────┐
# │ name                            ┆ count ┆ lat       ┆ lon       │
# │ ---                             ┆ ---   ┆ ---       ┆ ---       │
# │ str                             ┆ u32   ┆ f64       ┆ f64       │
# ╞═════════════════════════════════╪═══════╪═══════════╪═══════════╡
# │ BTM, Bangalore, Karnataka, Ind… ┆ 5124  ┆ 12.91636  ┆ 77.604733 │
# │ HSR, Bangalore, Karnataka, Ind… ┆ 2523  ┆ 12.900563 ┆ 77.649475 │
# │ Koramangala 5th Block, Bangalo… ┆ 2504  ┆ 12.934843 ┆ 77.618977 │
# │ JP Nagar, Bangalore, Karnataka… ┆ 2235  ┆ 12.909694 ┆ 77.586607 │
# │ Whitefield, Bangalore, Karnata… ┆ 2144  ┆ 12.969637 ┆ 77.749745 │
# └─────────────────────────────────┴───────┴───────────┴───────────┘, _body=<great_tables._gt_data.Body object at 0x306aaac60>, _boxhead=Boxhead([ColInfo(var='name', type=<ColInfoTypeEnum.default: 1>, column_label='name', column_align='left', column_width='200%'), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='center', column_width=None), ColInfo(var='lat', type=<ColInfoTypeEnum.default: 1>, column_label='lat', column_align='right', column_width=None), ColInfo(var='lon', type=<ColInfoTypeEnum.default: 1>, column_label='lon', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x309d44110>, _spanners=Spanners([]), _heading=Heading(title=Md(text='Zomato Restaurants Count & coordinates'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[Md(text='<br>*Source: Shan Singh*')], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x309d44500>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_ti ...

# %% [markdown]
# now in order to show-case it via Map(Heatmap) ,first we need to create BaseMap so that I can map our Heatmap on top of BaseMap !

# %%
def Generate_basemap():
    basemap = folium.Map(location=[12.97 , 77.59], zoom_start=11)
    return basemap

# %%
# Geographic heat maps are used to identify where something occurs, and demonstrate areas of high and low density...
from folium.plugins import HeatMap

# %%
basemap = Generate_basemap()

# %%
beng_rest_locations = beng_rest_locations.to_pandas()

# %%
HeatMap(beng_rest_locations[['lat', 'lon' , 'count']]).add_to(basemap)

# %%
#| label: fig-heatmap
#| fig-cap: "Zomato Restaurants Heatmap"
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aceaf02e5715327c1404a8c47d936de3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aceaf02e5715327c1404a8c47d936de3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aceaf02e5715327c1404a8c47d936de3 = L.map(
#                 &quot;map_aceaf02e5715327c1404a8c47d936de3&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cdfe2287324feb5da6f88b7c5fbc9bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cdfe2287324feb5da6f88b7c5fbc9bf.addTo(map_aceaf02e5715327c1404a8c47d936de3);
#
#
#             var heat_map_d936c7e659301f521a68ec2945a90e07 = L.heatLayer(
#                 [[12.9163603, 77.604733, 5124.0], [12.90056335, 77.64947470503677, 2523.0], [12.9348429, 77.6189768, 2504.0], [12.9096941, 77.5866067, 2235.0], [12.9696365, 77.7497448, 2144.0], [12.9962979, 77.5452778, 2083.0], [12.9399039, 77.5826382, 1926.0], [12.9552572, 77.6984163, 1846.0], [12.951855665820787, 77.60401135701308, 1630.0], [12.9377734, 77.6946701, 1286.0], [12.848759900000001, 77.64825295827616, 1258.0], [12.9277245, 77.6327822, 1238.0], [12.97364413065367, 77.60750847201824, 1218.0], [12.9364846, 77.6134783, 1181.0], [12.9390255, 77.6238477, 1156.0], [12.924013794074499, 77.6530859615482, 1065.0], [12.9778793, 77.6246697, 1023.0], [12.9327778, 77.6294052, 1017.0], [12.9755264, 77.6067902, 918.0], [12.9393328, 77.5539819, 906.0], [13.0221416, 77.6403368, 853.0], [12.97005075585937, 77.61696347752844, 812.0], [12.9986827, 77.615525, 727.0], [13.0027353, 77.5703253, 725.0], [12.9417261, 77.5755021, 684.0], [12.96668780296818, 77.59874713313619, 675.0], [13.0058357, 77.6281321, 664.0], [12.96381425, 77.72243691580387, 658.0], [13.016786206957198, 77.57261655105863, 649.0], [13.0093455, 77.6377094, 648.0], [13.0005359, 77.5496996, 591.0], [12.975700066194872, 77.60208311450552, 569.0], [12.972227072739638, 77.59866491535907, 529.0], [12.9575547, 77.5979099, 511.0], [12.986391, 77.6075416, 499.0], [12.9624669, 77.6381958, 496.0], [12.981439455383228, 77.59864251672357, 491.0], [12.9606321, 77.64249975, 446.0], [12.946605, 77.6289077, 439.0], [12.982242261028464, 77.60826495187648, 370.0], [12.975801449285402, 77.60169240479877, 352.0], [12.9408685, 77.617338, 320.0], [12.9934283, 77.5902145, 295.0], [12.9678074, 77.6568367, 272.0], [12.9489339, 77.5968273, 246.0], [12.9089453, 77.6239038, 238.0], [12.9282918, 77.6254034, 216.0], [12.9067683, 77.5595021, 195.0], [12.973936, 77.6509982, 194.0], [12.99118045, 77.54489175084052, 191.0], [13.0422794, 77.6248577, 187.0], [12.9931876, 77.5753419, 165.0], [13.037077, 77.6413572, 161.0], [12.9782998, 77.5723754, 155.0], [13.0358698, 77.6323597, 153.0], [12.981015523680384, 77.60213290057523, 151.0], [12.983856079729964, 77.58023300041461, 139.0], [12.965717999999999, 77.5762705372058, 126.0], [13.02383, 77.5529215, 119.0], [12.9567133, 77.74520818950934, 117.0], [12.9876393, 77.7377718, 113.0], [12.864107149999999, 77.55441638924378, 107.0], [12.9243692, 77.6242433, 102.0], [12.951773921360584, 77.60513523209458, 102.0], [12.9846713, 77.6790908, 101.0], [12.985098650000001, 77.66311735, 90.0], [12.9660722, 77.6125940647638, 80.0], [13.0227204, 77.595715, 80.0], [12.9578658, 77.6958748, 76.0], [13.0621474, 77.58006135480495, 53.0], [12.938455602031697, 77.63405129824629, 48.0], [12.9739905, 77.61449005854067, 44.0], [13.0394104, 77.5197351, 38.0], [12.975608, 77.5553564, 34.0], [12.957998, 77.6037312, 27.0], [12.988006763067125, 77.5872963178211, 27.0], [12.956753612862983, 77.5493748478081, 22.0], [12.983565054916333, 77.63904901323875, 22.0], [12.9367159, 77.5753743, 19.0], [13.007516, 77.695935, 18.0], [12.9055682, 77.5455438, 17.0], [13.0439323, 77.6254268017299, 14.0], [13.0382184, 77.5919, 14.0], [13.00196975, 77.52883895255425, 9.0], [12.9176571, 77.4837568, 9.0], [12.97339325, 77.61124684880099, 8.0], [13.0096524, 77.5530535343493, 6.0], [13.10850545, 77.58533304149645, 6.0], [13.0784743, 77.6068938, 3.0], [12.9274413, 77.5155224, 2.0], [13.0330515, 77.5332233, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_d936c7e659301f521a68ec2945a90e07.addTo(map_aceaf02e5715327c1404a8c47d936de3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ::: {.callout-note}
# You can interact with the above map by zooming in or out.
# :::

# %% [markdown]
# Majority of the Restaurants are avaiable in the city centre area.

# %% [markdown]
# ## Performing Marker Cluster Analysis

# %%
from folium.plugins import FastMarkerCluster

# %%
basemap = Generate_basemap()

# %%
FastMarkerCluster(beng_rest_locations[['lat', 'lon' , 'count']]).add_to(basemap)

# %%
#| label: fig-marker-cluster
#| fig-cap: "Zomato Marker Cluster Map"
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17cbceebc6977406b0ba4dabe4845e3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17cbceebc6977406b0ba4dabe4845e3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17cbceebc6977406b0ba4dabe4845e3e = L.map(
#                 &quot;map_17cbceebc6977406b0ba4dabe4845e3e&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f075f7290da7be2766ae2e53f7ff0461 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f075f7290da7be2766ae2e53f7ff0461.addTo(map_17cbceebc6977406b0ba4dabe4845e3e);
#
#
#             var fast_marker_cluster_8488cc1e80448b5c4ae8e0a4bd471240 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[12.9163603, 77.604733, 5124.0], [12.90056335, 77.64947470503677, 2523.0], [12.9348429, 77.6189768, 2504.0], [12.9096941, 77.5866067, 2235.0], [12.9696365, 77.7497448, 2144.0], [12.9962979, 77.5452778, 2083.0], [12.9399039, 77.5826382, 1926.0], [12.9552572, 77.6984163, 1846.0], [12.951855665820787, 77.60401135701308, 1630.0], [12.9377734, 77.6946701, 1286.0], [12.848759900000001, 77.64825295827616, 1258.0], [12.9277245, 77.6327822, 1238.0], [12.97364413065367, 77.60750847201824, 1218.0], [12.9364846, 77.6134783, 1181.0], [12.9390255, 77.6238477, 1156.0], [12.924013794074499, 77.6530859615482, 1065.0], [12.9778793, 77.6246697, 1023.0], [12.9327778, 77.6294052, 1017.0], [12.9755264, 77.6067902, 918.0], [12.9393328, 77.5539819, 906.0], [13.0221416, 77.6403368, 853.0], [12.97005075585937, 77.61696347752844, 812.0], [12.9986827, 77.615525, 727.0], [13.0027353, 77.5703253, 725.0], [12.9417261, 77.5755021, 684.0], [12.96668780296818, 77.59874713313619, 675.0], [13.0058357, 77.6281321, 664.0], [12.96381425, 77.72243691580387, 658.0], [13.016786206957198, 77.57261655105863, 649.0], [13.0093455, 77.6377094, 648.0], [13.0005359, 77.5496996, 591.0], [12.975700066194872, 77.60208311450552, 569.0], [12.972227072739638, 77.59866491535907, 529.0], [12.9575547, 77.5979099, 511.0], [12.986391, 77.6075416, 499.0], [12.9624669, 77.6381958, 496.0], [12.981439455383228, 77.59864251672357, 491.0], [12.9606321, 77.64249975, 446.0], [12.946605, 77.6289077, 439.0], [12.982242261028464, 77.60826495187648, 370.0], [12.975801449285402, 77.60169240479877, 352.0], [12.9408685, 77.617338, 320.0], [12.9934283, 77.5902145, 295.0], [12.9678074, 77.6568367, 272.0], [12.9489339, 77.5968273, 246.0], [12.9089453, 77.6239038, 238.0], [12.9282918, 77.6254034, 216.0], [12.9067683, 77.5595021, 195.0], [12.973936, 77.6509982, 194.0], [12.99118045, 77.54489175084052, 191.0], [13.0422794, 77.6248577, 187.0], [12.9931876, 77.5753419, 165.0], [13.037077, 77.6413572, 161.0], [12.9782998, 77.5723754, 155.0], [13.0358698, 77.6323597, 153.0], [12.981015523680384, 77.60213290057523, 151.0], [12.983856079729964, 77.58023300041461, 139.0], [12.965717999999999, 77.5762705372058, 126.0], [13.02383, 77.5529215, 119.0], [12.9567133, 77.74520818950934, 117.0], [12.9876393, 77.7377718, 113.0], [12.864107149999999, 77.55441638924378, 107.0], [12.9243692, 77.6242433, 102.0], [12.951773921360584, 77.60513523209458, 102.0], [12.9846713, 77.6790908, 101.0], [12.985098650000001, 77.66311735, 90.0], [12.9660722, 77.6125940647638, 80.0], [13.0227204, 77.595715, 80.0], [12.9578658, 77.6958748, 76.0], [13.0621474, 77.58006135480495, 53.0], [12.938455602031697, 77.63405129824629, 48.0], [12.9739905, 77.61449005854067, 44.0], [13.0394104, 77.5197351, 38.0], [12.975608, 77.5553564, 34.0], [12.957998, 77.6037312, 27.0], [12.988006763067125, 77.5872963178211, 27.0], [12.956753612862983, 77.5493748478081, 22.0], [12.983565054916333, 77.63904901323875, 22.0], [12.9367159, 77.5753743, 19.0], [13.007516, 77.695935, 18.0], [12.9055682, 77.5455438, 17.0], [13.0439323, 77.6254268017299, 14.0], [13.0382184, 77.5919, 14.0], [13.00196975, 77.52883895255425, 9.0], [12.9176571, 77.4837568, 9.0], [12.97339325, 77.61124684880099, 8.0], [13.0096524, 77.5530535343493, 6.0], [13.10850545, 77.58533304149645

# %% [markdown]
# ::: {.callout-note}
# You can interact with the above map by zooming in or out.
# :::

# %% [markdown]
# ## Mapping all the markers of places of Bangalore

# %% [markdown]
# Plotting Markers on the Map :
#
# Folium gives a folium.Marker() class for plotting markers on a map
#
# Just pass the latitude and longitude of the location, mention the popup and tooltip and add it to the map.
#
# Plotting markers is a two-step process.
#
# 1) you need to create a base map on which your markers will be placed
# 2) and then add your markers to it:

# %%
m = Generate_basemap()

# %%
# Add points to the map
for index, row in beng_rest_locations.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['count']).add_to(m)

# %%
#| label: fig-markers
#| fig-cap: "Zomato Restaurants Marker Map"
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2e54cac08996d1c03bfa7ac88648758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2e54cac08996d1c03bfa7ac88648758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2e54cac08996d1c03bfa7ac88648758 = L.map(
#                 &quot;map_a2e54cac08996d1c03bfa7ac88648758&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8f5ab82aec7ae6a29e386fbc52d5d8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8f5ab82aec7ae6a29e386fbc52d5d8c.addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#             var marker_ab3083c417aee4a0a84d1fd759b494c9 = L.marker(
#                 [12.9163603, 77.604733],
#                 {
# }
#             ).addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#         var popup_a3d057317592830d1a6b0f0284ca97b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be82b778aea9cac624ed0acaae886408 = $(`&lt;div id=&quot;html_be82b778aea9cac624ed0acaae886408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5124&lt;/div&gt;`)[0];
#                 popup_a3d057317592830d1a6b0f0284ca97b8.setContent(html_be82b778aea9cac624ed0acaae886408);
#
#
#
#         marker_ab3083c417aee4a0a84d1fd759b494c9.bindPopup(popup_a3d057317592830d1a6b0f0284ca97b8)
#         ;
#
#
#
#
#             var marker_67fce8e4d111fb1398b13ed221d84f5d = L.marker(
#                 [12.90056335, 77.64947470503677],
#                 {
# }
#             ).addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#         var popup_9f67181d391e520caed217eab9579d0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_152f64b453360183de0e394ea871588a = $(`&lt;div id=&quot;html_152f64b453360183de0e394ea871588a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2523&lt;/div&gt;`)[0];
#                 popup_9f67181d391e520caed217eab9579d0a.setContent(html_152f64b453360183de0e394ea871588a);
#
#
#
#         marker_67fce8e4d111fb1398b13ed221d84f5d.bindPopup(popup_9f67181d391e520caed217eab9579d0a)
#         ;
#
#
#
#
#             var marker_b99abab1afbf9bb09789f5735eb11eec = L.marker(
#                 [12.9348429, 77.6189768],
#                 {
# }
#             ).addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#         var popup_74be3124eedf318861eaf62a84872688 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_361c67b00dfd40941fbd81265691dd30 = $(`&lt;div id=&quot;html_361c67b00dfd40941fbd81265691dd30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2504&lt;/div&gt;`)[0];
#                 popup_74be3124eedf318861eaf62a84872688.setContent(html_361c67b00dfd40941fbd81265691dd30);
#
#
#
#         marker_b99abab1afbf9bb09789f5735eb11eec.bindPopup(popup_74be3124eedf318861eaf62a84872688)
#         ;
#
#
#
#
#             var marker_1b74b839e9704705ed65a8de81ba9e12 = L.marker(
#                 [12.9096941, 77.5866067],
#                 {
# }
#             ).addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#         var popup_ecfa44deaea2f58ab8555d8f607cde52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b9be286fbc0b7c7b342c1ca2b31a76 = $(`&lt;div id=&quot;html_50b9be286fbc0b7c7b342c1ca2b31a76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2235&lt;/div&gt;`)[0];
#                 popup_ecfa44deaea2f58ab8555d8f607cde52.setContent(html_50b9be286fbc0b7c7b342c1ca2b31a76);
#
#
#
#         marker_1b74b839e9704705ed65a8de81ba9e12.bindPopup(popup_ecfa44deaea2f58ab8555d8f607cde52)
#         ;
#
#
#
#
#             var marker_64de368db766a1f1bfe73f2701a9204f = L.marker(
#                 [12.9696365, 77.7497448],
#                 {
# }
#             ).addTo(map_a2e54cac08996d1c03bfa7ac88648758);
#
#
#         var popup_fdc8745bc0844d6ecaf9bc178de032ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f5e237b7293df91680e4794cc0bd6ef = $(`&lt;div id=&quot;html_1f5e237b7293df91680e4794cc0bd6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2144&lt;/div&gt;`)[0];
#                 popup_fdc8745bc0844d6ecaf9bc178de032ed.setContent(html_1f5e237b7293df91680e4794cc0bd6ef);
#
#
#
#         marker_64de368db766a1f1bfe73f2701a9204f.bindPopup(popup_fdc8745bc0844d6ecaf9bc178de032ed)
#         ;
#
#
#
#
#             var marker_1358057c877044edd20f3089187326bc = L.marker(
#                 [12.9962979, 77.5452778],
#                 {
# }
#             ).addTo(map_a2e54

# %% [markdown]
# ::: {.callout-note}
# You can interact with the above map by zooming in or out.
# :::

# %% [markdown]
# **Rate field cleaning**
#
# In order to Analyse where are the restaurants situated with high average rate, first we need to clean 'rate' feature

# %%
(
    df.filter(
        pl.col('rate').str.contains('^([^0-9]*)$')
    )
    .select('rate')
    .unique()
    .to_dicts()
)
# Out:
# [{'rate': '-'}, {'rate': 'NEW'}]

# %%
pl.Series(df.select('rate')).is_null().sum()
# Out:
# 7754

# %%
# approximately 15% of your rating belongs to missing values
pl.Series(df.select('rate')).is_null().sum()/pl.Series(df.select('rate')).len()*100
# Out:
# 14.999226245744351

# %%
df = (
    df.drop_nulls(subset='rate')
        .with_columns(
            pl.col('rate').replace(['NEW', '-',], ['0', '0'])
        )
        .with_columns(
            rating=pl.col('rate').str.replace('/5', '')
        )
        .with_columns(
            pl.col('rating').str.strip_chars()
        )
        .cast({'rating': pl.Float32})
)

# %%
df.select('rating').unique().to_dicts()
# Out:
# [{'rating': 2.4000000953674316},
#  {'rating': 2.299999952316284},
#  {'rating': 0.0},
#  {'rating': 3.5},
#  {'rating': 4.099999904632568},
#  {'rating': 4.400000095367432},
#  {'rating': 4.699999809265137},
#  {'rating': 4.900000095367432},
#  {'rating': 2.700000047683716},
#  {'rating': 3.9000000953674316},
#  {'rating': 3.799999952316284},
#  {'rating': 3.4000000953674316},
#  {'rating': 3.0},
#  {'rating': 2.5999999046325684},
#  {'rating': 3.299999952316284},
#  {'rating': 4.199999809265137},
#  {'rating': 2.200000047683716},
#  {'rating': 4.0},
#  {'rating': 4.5},
#  {'rating': 2.5},
#  {'rating': 3.5999999046325684},
#  {'rating': 3.700000047683716},
#  {'rating': 2.0999999046325684},
#  {'rating': 4.800000190734863},
#  {'rating': 3.200000047683716},
#  {'rating': 2.799999952316284},
#  {'rating': 4.300000190734863},
#  {'rating': 2.9000000953674316},
#  {'rating': 2.0},
#  {'rating': 4.599999904632568},
#  {'rating': 3.0999999046325684},
#  {'rating': 1.7999999523162842}]

# %% [markdown]
# ## Most highest rated restaurants

# %%
df.select('name','rate','votes','location','dish_liked','rating').sort('rating', descending=True).head()
# Out:
# shape: (5, 6)
# ┌──────────────────────────┬───────┬───────┬───────────────────┬──────────────────────────┬────────┐
# │ name                     ┆ rate  ┆ votes ┆ location          ┆ dish_liked               ┆ rating │
# │ ---                      ┆ ---   ┆ ---   ┆ ---               ┆ ---                      ┆ ---    │
# │ str                      ┆ str   ┆ i64   ┆ str               ┆ str                      ┆ f32    │
# ╞══════════════════════════╪═══════╪═══════╪═══════════════════╪══════════════════════════╪════════╡
# │ Byg Brewski Brewing      ┆ 4.9/5 ┆ 16345 ┆ Sarjapur Road,    ┆ Cocktails, Dahi Kebab,   ┆ 4.9    │
# │ Company                  ┆       ┆       ┆ Bangalore, Karn…  ┆ Rajma C…                 ┆        │
# │ Byg Brewski Brewing      ┆ 4.9/5 ┆ 16345 ┆ Sarjapur Road,    ┆ Cocktails, Dahi Kebab,   ┆ 4.9    │
# │ Company                  ┆       ┆       ┆ Bangalore, Karn…  ┆ Rajma C…                 ┆        │
# │ Byg Brewski Brewing      ┆ 4.9/5 ┆ 16345 ┆ Sarjapur Road,    ┆ Cocktails, Dahi Kebab,   ┆ 4.9    │
# │ Company                  ┆       ┆       ┆ Bangalore, Karn…  ┆ Rajma C…                 ┆        │
# │ Belgian Waffle Factory   ┆ 4.9/5 ┆ 1746  ┆ Brigade Road,     ┆ Coffee, Berryblast,      ┆ 4.9    │
# │                          ┆       ┆       ┆ Bangalore, Karna… ┆ Nachos, Ch…              ┆        │
# │ Belgian Waffle Factory   ┆ 4.9/5 ┆ 1746  ┆ Brigade Road,     ┆ Coffee, Berryblast,      ┆ 4.9    │
# │                          ┆       ┆       ┆ Bangalore, Karna… ┆ Nachos, Ch…              ┆        │
# └──────────────────────────┴───────┴───────┴───────────────────┴──────────────────────────┴────────┘

# %%
grp_df = (
    df.group_by('location').agg(pl.col('rating').mean(), pl.col('name').count())
        .rename({'location':'name', 'rating':'avg_rating', 'name':'count'})
)

# %%
grp_df
# Out:
# shape: (92, 3)
# ┌─────────────────────────────────┬────────────┬───────┐
# │ name                            ┆ avg_rating ┆ count │
# │ ---                             ┆ ---        ┆ ---   │
# │ str                             ┆ f32        ┆ u32   │
# ╞═════════════════════════════════╪════════════╪═══════╡
# │ Brookefield, Bangalore, Karnat… ┆ 3.374697   ┆ 581   │
# │ Thippasandra, Bangalore, Karna… ┆ 3.095396   ┆ 152   │
# │ Electronic City, Bangalore, Ka… ┆ 3.04191    ┆ 964   │
# │ Koramangala 1st Block, Bangalo… ┆ 3.263946   ┆ 965   │
# │ Koramangala 3rd Block, Bangalo… ┆ 3.978755   ┆ 193   │
# │ …                               ┆ …          ┆ …     │
# │ RT Nagar, Bangalore, Karnataka… ┆ 3.278125   ┆ 64    │
# │ Jalahalli, Bangalore, Karnatak… ┆ 3.486956   ┆ 23    │
# │ Commercial Street, Bangalore, … ┆ 3.109709   ┆ 309   │
# │ Banaswadi, Bangalore, Karnatak… ┆ 3.362927   ┆ 499   │
# │ Koramangala 5th Block, Bangalo… ┆ 3.901511   ┆ 2381  │
# └─────────────────────────────────┴────────────┴───────┘

# %% [markdown]
# lets consider only those restaurants who have send atleast 400 orders

# %%
temp_df = grp_df.filter(pl.col('count')>400)

# %%
temp_df.shape
# Out:
# (35, 3)

# %%
temp_df
# Out:
# shape: (35, 3)
# ┌─────────────────────────────────┬────────────┬───────┐
# │ name                            ┆ avg_rating ┆ count │
# │ ---                             ┆ ---        ┆ ---   │
# │ str                             ┆ f32        ┆ u32   │
# ╞═════════════════════════════════╪════════════╪═══════╡
# │ Brookefield, Bangalore, Karnat… ┆ 3.374697   ┆ 581   │
# │ Electronic City, Bangalore, Ka… ┆ 3.04191    ┆ 964   │
# │ Koramangala 1st Block, Bangalo… ┆ 3.263946   ┆ 965   │
# │ Bannerghatta Road, Bangalore, … ┆ 3.271675   ┆ 1324  │
# │ HSR, Bangalore, Karnataka, Ind… ┆ 3.484063   ┆ 2128  │
# │ …                               ┆ …          ┆ …     │
# │ Richmond Road, Bangalore, Karn… ┆ 3.688013   ┆ 634   │
# │ Koramangala 7th Block, Bangalo… ┆ 3.747846   ┆ 1089  │
# │ Frazer Town, Bangalore, Karnat… ┆ 3.56488    ┆ 578   │
# │ Banaswadi, Bangalore, Karnatak… ┆ 3.362927   ┆ 499   │
# │ Koramangala 5th Block, Bangalo… ┆ 3.901511   ┆ 2381  │
# └─────────────────────────────────┴────────────┴───────┘

# %%
rest_loc
# Out:
# shape: (91, 3)
# ┌─────────────────────────────────┬───────────┬───────────┐
# │ name                            ┆ lat       ┆ lon       │
# │ ---                             ┆ ---       ┆ ---       │
# │ str                             ┆ f64       ┆ f64       │
# ╞═════════════════════════════════╪═══════════╪═══════════╡
# │ Sahakara Nagar, Bangalore, Kar… ┆ 13.062147 ┆ 77.580061 │
# │ Kaggadasapura, Bangalore, Karn… ┆ 12.984671 ┆ 77.679091 │
# │ Infantry Road, Bangalore, Karn… ┆ 12.981016 ┆ 77.602133 │
# │ CV Raman Nagar, Bangalore, Kar… ┆ 12.985099 ┆ 77.663117 │
# │ JP Nagar, Bangalore, Karnataka… ┆ 12.909694 ┆ 77.586607 │
# │ …                               ┆ …         ┆ …         │
# │ Seshadripuram, Bangalore, Karn… ┆ 12.993188 ┆ 77.575342 │
# │ Jakkur, Bangalore, Karnataka, … ┆ 13.078474 ┆ 77.606894 │
# │ Bommanahalli, Bangalore, Karna… ┆ 12.908945 ┆ 77.623904 │
# │ Kammanahalli, Bangalore, Karna… ┆ 13.009346 ┆ 77.637709 │
# │ Nagawara, Bangalore, Karnataka… ┆ 13.042279 ┆ 77.624858 │
# └─────────────────────────────────┴───────────┴───────────┘

# %% [markdown]
# lets merge both the dataframe so that we can get coordinates as well

# %%
ratings_locations = temp_df.join(rest_loc, on='name')

# %%
ratings_locations
# Out:
# shape: (35, 5)
# ┌─────────────────────────────────┬────────────┬───────┬───────────┬───────────┐
# │ name                            ┆ avg_rating ┆ count ┆ lat       ┆ lon       │
# │ ---                             ┆ ---        ┆ ---   ┆ ---       ┆ ---       │
# │ str                             ┆ f32        ┆ u32   ┆ f64       ┆ f64       │
# ╞═════════════════════════════════╪════════════╪═══════╪═══════════╪═══════════╡
# │ JP Nagar, Bangalore, Karnataka… ┆ 3.412929   ┆ 1849  ┆ 12.909694 ┆ 77.586607 │
# │ Koramangala 4th Block, Bangalo… ┆ 3.814351   ┆ 864   ┆ 12.932778 ┆ 77.629405 │
# │ Whitefield, Bangalore, Karnata… ┆ 3.384171   ┆ 1693  ┆ 12.969637 ┆ 77.749745 │
# │ Bannerghatta Road, Bangalore, … ┆ 3.271675   ┆ 1324  ┆ 12.951856 ┆ 77.604011 │
# │ Jayanagar, Bangalore, Karnatak… ┆ 3.61525    ┆ 1718  ┆ 12.939904 ┆ 77.582638 │
# │ …                               ┆ …          ┆ …     ┆ …         ┆ …         │
# │ Ulsoor, Bangalore, Karnataka, … ┆ 3.541396   ┆ 901   ┆ 12.977879 ┆ 77.62467  │
# │ Frazer Town, Bangalore, Karnat… ┆ 3.56488    ┆ 578   ┆ 12.998683 ┆ 77.615525 │
# │ Indiranagar, Bangalore, Karnat… ┆ 3.652168   ┆ 1936  ┆ 12.996298 ┆ 77.545278 │
# │ Koramangala 6th Block, Bangalo… ┆ 3.662465   ┆ 1111  ┆ 12.939025 ┆ 77.623848 │
# │ Kammanahalli, Bangalore, Karna… ┆ 3.499809   ┆ 525   ┆ 13.009346 ┆ 77.637709 │
# └─────────────────────────────────┴────────────┴───────┴───────────┴───────────┘

# %%
basemap = Generate_basemap()

# %%
ratings_locations = ratings_locations.to_pandas()

# %%
HeatMap(ratings_locations[['lat', 'lon' , 'avg_rating']]).add_to(basemap)

# %%
#| label: fig-heatmap-rated
#| fig-cap: "Highest-rated Zomato Restaurants Heatmap"
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb7bee2607332a108ee881a8a4f7dab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb7bee2607332a108ee881a8a4f7dab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb7bee2607332a108ee881a8a4f7dab = L.map(
#                 &quot;map_9fb7bee2607332a108ee881a8a4f7dab&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dacd2c49b0f0db8e175f9266e6b89a6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dacd2c49b0f0db8e175f9266e6b89a6f.addTo(map_9fb7bee2607332a108ee881a8a4f7dab);
#
#
#             var heat_map_180c89aedd60aeb4ee8a9fc2a9ff7581 = L.heatLayer(
#                 [[12.9096941, 77.5866067, 3.412928581237793], [12.9327778, 77.6294052, 3.8143506050109863], [12.9696365, 77.7497448, 3.384171485900879], [12.951855665820787, 77.60401135701308, 3.271674633026123], [12.9399039, 77.5826382, 3.6152496337890625], [13.0005359, 77.5496996, 3.4223835468292236], [12.97364413065367, 77.60750847201824, 3.595848798751831], [12.848759900000001, 77.64825295827616, 3.041909694671631], [12.9393328, 77.5539819, 3.3732941150665283], [12.9163603, 77.604733, 3.296131134033203], [12.9364846, 77.6134783, 3.7478458881378174], [13.0221416, 77.6403368, 3.529143810272217], [12.981439455383228, 77.59864251672357, 3.9010486602783203], [12.96668780296818, 77.59874713313619, 3.8445770740509033], [12.9417261, 77.5755021, 3.478184700012207], [12.9552572, 77.6984163, 3.4005300998687744], [12.9277245, 77.6327822, 3.2639455795288086], [12.9755264, 77.6067902, 3.740546464920044], [12.972227072739638, 77.59866491535907, 4.042891502380371], [13.016786206957198, 77.57261655105863, 3.583172082901001], [12.9377734, 77.6946701, 3.309832811355591], [12.924013794074499, 77.6530859615482, 3.4735591411590576], [12.9348429, 77.6189768, 3.9015111923217773], [13.0058357, 77.6281321, 3.362927198410034], [12.90056335, 77.64947470503677, 3.484062910079956], [12.9624669, 77.6381958, 3.3855490684509277], [12.975700066194872, 77.60208311450552, 3.963092088699341], [12.97005075585937, 77.61696347752844, 3.6880125999450684], [13.0027353, 77.5703253, 3.66823410987854], [12.96381425, 77.72243691580387, 3.374696969985962], [12.9778793, 77.6246697, 3.541396379470825], [12.9986827, 77.615525, 3.564880132675171], [12.9962979, 77.5452778, 3.652167558670044], [12.9390255, 77.6238477, 3.6624653339385986], [13.0093455, 77.6377094, 3.4998092651367188]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_180c89aedd60aeb4ee8a9fc2a9ff7581.addTo(map_9fb7bee2607332a108ee881a8a4f7dab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ::: {.callout-note}
# You can interact with the above map by zooming in or out.
# :::

# %% [markdown]
# ## Conclusions
#
# Python, with its powerful libraries and ease of use, has become an indispensable tool for geospatial analysis.
# By leveraging the capabilities of libraries like GeoPandas, Shapely, and folium, data scientists can effectively explore and analyze geospatial data, gain valuable insights, and make informed decisions.
#
# In this article, we have shown a brief overview of geospatial analysis in Python.

# %% [markdown]
# ## References
#
# * Singh, S (2024) [Spatial Analysis & Geospatial Data Science in Python](https://www.udemy.com/course/spatial-data-science-in-python)
# * Tenkanen, H et al (2022) [Introduction to Python for Geographic Data Analysis](https://pythongis.org)

# %% [markdown]
# ## Contact
#
# **Jesus L. Monroy**
# <br>
# *Economist & Data Scientist*
#
# [Medium](https://medium.com/@jesuslm) | [Linkedin](https://www.linkedin.com/in/j3sus-lm) | [Twitter](https://x.com/j3suslm)
