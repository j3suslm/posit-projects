# %% [raw]
# ---
# title: National Guard’s Deployed Personnel in Mexico
# author-title: Author
# author: Jesus L. Monroy
# abstract-title: Abstract
# abstract: |
#   Mexico’s National Guard is a relatively new security force established in 2019. It was created to address the country’s high crime rates and complement traditional law enforcement.
# published-title: Published
# date: '2024-04-19'
# date-format: MMM, YYYY
# toc: true
# toc-title: Table of Contents
# toc-location: left
# page-layout: full
# execute:
#   echo: true
# format:
#   html:
#     page-layout: full
#     embed-resources: true
#     code-fold: show
#     html-math-method: mathml
#     other-links:
#           - text: Medium
#             icon: medium
#             href: https://medium.com/@jesus_lmonroy
#           - text: Linkedin
#             icon: linkedin
#             href: https://www.linkedin.com/in/j3sus-lmonroy
#           - text: Twitter
#             icon: twitter
#             href: https://x.com/j3suslm
# code-line-numbers: false
# code-copy: false
# code-overflow: wrap
# jupyter: python3
# categories: [python]
# image: images/gn.png
# ---

# %% [markdown]
# ![GN personnel](images/gn.png)

# %% [markdown]
# ### Environment settings

# %%
import numpy as np
import pandas as pd
from datawrapper import Datawrapper
import json
import warnings
warnings.filterwarnings('ignore')

# %%
# Token gotten from datawrapper
filename = 'credentials.json'
# read json file
with open(filename) as f:
    keys = json.load(f)
# read credentials
token = keys['datawrapper_api']

# %%
# Access datawrapper api
dw = Datawrapper(access_token = token)

# %% [markdown]
# ## National Guard
#
# Mexico’s National Guard is a relatively new security force established in 2019.
# It was created to address the country’s high crime rates and complement traditional law enforcement.
#
# - **Formation**
#
# In 2019, it emerged by merging elements of the Federal Police, Military Police, and Naval Police.
#
# - **Mission**
#
# The National Guard was intended to be a gendarmerie, focusing on territorial defense and public security tasks like crime prevention and patrolling.
#
# - **Structure**
#
# Initially envisioned under civilian control, a 2022 reform transferred command to the Ministry of National Defense, sparking controversy.
#
# - **Current Status**
#
# The National Guard’s role is evolving. It still tackles crime, but also handles tasks like border control and disaster relief.

# %% [markdown]
# ## Display interactive chart
#
# ::: {#fig-datawrapper}
# ```{=html}
# <iframe width="800" height="750" src="https://datawrapper.dwcdn.net/Sr51n/4/" title="Crime Incidence in Mexico" data-external="1"></iframe>
# ```
# Datawrapper Interactive Chart
# :::

# %% [markdown]
# ::: {.callout-note}
# ## Info
# You can hover the mouse over the map to get additional information.
# :::

# %% [markdown]
# ## References
#
# - [What is Guardia Nacional?](https://seguridadviacivil.ibero.mx/2023/04/18/que-es-la-guardia-nacional-en-2023/)
# - [Gobierno de Mexico](https://www.gob.mx/sspc/prensa/mas-de-56-mil-elementos-de-la-guardia-nacional-estan-desplegados-en-150-coordinaciones-regionales-del-pais-212953)

# %% [markdown]
# ## Contact
#
# **Jesus L. Monroy**
# <br>
# *Economist & Data Scientist*
#
# [Medium](https://medium.com/@jesuslm) | [Linkedin](https://www.linkedin.com/in/j3sus-lm) | [Twitter](https://x.com/j3suslm)
